# %%
import os
import sys

import pandas as pd
import numpy as np

from copy import deepcopy

import matplotlib.pyplot as plt
import seaborn as sns

from calcmodule import MeanAbsError, Correlation, MeanError, mMAE, BiasCorrection
from calcmodule import cohen_d, LMEM, TukeyHSD, Longitudinal_performance
from scipy.stats import ttest_ind, f_oneway, pearsonr, spearmanr

from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multitest import fdrcorrection


import warnings
warnings.filterwarnings("ignore")

# %%
BASE = "/NFS/Users/moonsh/thesis/result/"
SAVEPATH = '/NFS/Users/moonsh/thesis/result/merge/'
PHENOPATH = '/NFS/Users/moonsh/thesis/data/'
analysis_type = ['train-test', 'longitudinal', 'BAG',] # test-retest
model_type = ['Center', "FedAvg", "FedProx", "MOON"]

data_name = ['HCP', 'NKI-RK', 'UCLA-CNP', 'OAS3', 'JBNU', 'SALD', 'CamCAN', 'DecNef', 'DLBS', 'IXI']
ind_data_name = ['ADNI', 'COBRE', 'MCIC', 'NUSDAST', 'OAS4', 'OAS2', 'SLIM', 'CoRR', 'fcon1000']

total_data_name = data_name + ind_data_name

# ADNI, COBRE, MCIC, NUSDAST, OAS4: Utility
# OAS2, SLIM: Consistency
# CoRR, fcon1000: Generalizabilitiy

patient_data = ["ADNI", "COBRE", "MCIC", "NUSDAST", "OAS4"]
pin_col = ["Age", "Sex(1=m,2=f)", "ImageFile"]

# %% [markdown]
# ## Merge Result DataFrame

# %%
# for _type in model_type:
#     print(_type)
#     _type_path = BASE+"original"+f"/{_type}/"
#     # _type_path = BASE+f"/{_type}/"
#     wandb_proj_name_list = os.listdir(_type_path)
#     print(wandb_proj_name_list)

#     for d_name in ['OAS2', "SLIM"]:
#         merge_df = pd.DataFrame()

#         for rp_idx, wandb_proj_name in enumerate(wandb_proj_name_list):
#             rp_idx += 1
#             pwd = _type_path + "/" + wandb_proj_name
#             df_list = os.listdir(pwd)
            
#             for df_name in df_list:
#                 if d_name in df_name:
#                     df = pd.read_csv(pwd + "/" + df_name)
#                     df.drop_duplicates(subset='Subject', keep='first', inplace=True)
#                     df.sort_values(by='Subject', inplace=True)

#                     if rp_idx == 1:
#                         merge_df['Subject'] = df['Subject']
#                         merge_df['Age'] = df['Age']

#                     merge_df[f"pred_{rp_idx}"] = df['pred_age']

#                     if rp_idx == 5:
#                         merge_df['avg_pred_age'] = merge_df[[f"pred_{i+1}" for i in range(5)]].mean(axis=1)
#                         merge_df['mode'] = df['mode']                        

#                         if d_name in patient_data:
#                             pheno_df = pd.read_csv(os.path.join(PHENOPATH, d_name, f"{d_name}_Phenotype_total.csv"))
#                             pheno_col = pheno_df.columns
#                             filtered_col = [col for col in pheno_col if col not in pin_col]
#                             pheno_df = pheno_df[filtered_col]

#                             merge_df = pd.merge(merge_df, pheno_df, on='Subject', how='inner')
#                     break
#         folder = os.path.join(SAVEPATH, f"{d_name}")
        
#         if not os.path.exists(folder):
#             os.makedirs(folder)

#         merge_df.to_csv(os.path.join(SAVEPATH, d_name, f"{d_name}_{_type}_follow.csv"), index=False)

# %% [markdown]
# ## Train-Test Performance

# %%
MERGEBASE = "/NFS/Users/moonsh/thesis/result/merge/"

# %%
performance_mae_df = pd.DataFrame(columns=['Dataset', 'Center', 'Local', 'FedAvg', 'FedProx', 'MOON'])
performance_r2_df = pd.DataFrame(columns=['Dataset', 'Center', 'Local', 'FedAvg', 'FedProx', 'MOON'])

mixed_performance_mae_df = pd.DataFrame(columns=['Dataset', 'Center', 'Local', 'FedAvg', 'FedProx', 'MOON'])
mixed_performance_r2_df = pd.DataFrame(columns=['Dataset', 'Center', 'Local', 'FedAvg', 'FedProx', 'MOON'])

df_per_dataset = []

fig, axs = plt.subplots(2, 5, figsize=(28, 11))

for idx, name in enumerate(data_name):

    temp_model_df = pd.DataFrame()

    ax = axs[idx//5, idx%5]
    TEMPPATH = os.path.join(MERGEBASE, name)

    new_row_mae = {'Dataset': name}
    new_row_r2 = {'Dataset': name}

    mixed_row_mae = {'Dataset': name}
    mixed_row_r2 = {'Dataset': name}

    viz_df = pd.DataFrame(columns=['Dataset', 'Center', 'Local', 'FedAvg', 'FedProx', 'MOON'])

    for _type in model_type: # ['Center', "Local", "FedAvg", "FedProx", "MOON"]
        temp_save_df = pd.DataFrame()

        df = pd.read_csv(os.path.join(TEMPPATH, f"{name}_{_type}.csv"))

        temp_save_df['Model'] = [_type]*len(df)
        temp_save_df['AE'] = np.abs(df['Age'] - df['avg_pred_age'])
        temp_save_df = pd.concat([temp_save_df, df], axis=1)

        test_df = df[df['mode'] == 'Test']
        temp_mae_list = []
        temp_r2_list = []
        temp_df = pd.DataFrame()

        for pred_idx in range(1, 6):
            temp_mae = MeanAbsError(test_df, 'Age', f"pred_{pred_idx}")
            temp_r2 = Correlation(test_df, 'Age', f"pred_{pred_idx}", method='r2')
            temp_mae_list.extend([temp_mae])
            temp_r2_list.extend([temp_r2])
        
        
        mae_mean = np.mean(temp_mae_list)
        mae_std = np.std(temp_mae_list)

        r2_mean = np.mean(temp_r2_list)
        r2_std = np.std(temp_r2_list)

        new_row_mae.update({_type: f"{mae_mean:.3f}±{mae_std:.3f}"})
        new_row_r2.update({_type: f"{r2_mean:.3f}±{r2_std:.3f}"})

        mixed_MAE = MeanAbsError(test_df, 'Age', "avg_pred_age")
        mixed_r2 = Correlation(test_df, 'Age', "avg_pred_age", method='r2')

        mixed_row_mae.update({_type: f"{mixed_MAE:.3f}"})
        mixed_row_r2.update({_type: f"{mixed_r2:.3f}"})

        temp_df['model'] = [_type]*5
        temp_df['mae'] = temp_mae_list
        temp_df['r2'] = temp_r2_list

        viz_df = pd.concat([viz_df, temp_df], axis=0)

        temp_model_df = pd.concat([temp_model_df, temp_save_df], axis=0)
    
    df_per_dataset.append(temp_model_df)
    sns.boxplot(data=viz_df, x="model", y="mae", width=0.6, palette="Set3", ax=ax)

    ax.set_title(f"[{name}] MAE Performance", fontsize=14)
    ax.set_xlabel("Model", fontsize=12)
    ax.set_ylabel("MAE", fontsize=12)

    if name == 'CamCAN':
        ax.set_ylim(2, 11.5)
    elif name == 'DecNef' or name == 'IXI':
        ax.set_ylim(3.5, 7)

    else:
        ax.set_ylim(2, 7)
         
    mixed_performance_mae_df = pd.concat([mixed_performance_mae_df, pd.DataFrame(mixed_row_mae, index=[0])], axis=0)
    mixed_performance_r2_df = pd.concat([mixed_performance_r2_df, pd.DataFrame(mixed_row_r2, index=[0])], axis=0)

    performance_mae_df = pd.concat([performance_mae_df, pd.DataFrame(new_row_mae, index=[0])], axis=0)
    performance_r2_df = pd.concat([performance_r2_df, pd.DataFrame(new_row_r2, index=[0])], axis=0)

# plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', "MAE_Performance.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 5, figsize=(28, 11))

colors = sns.color_palette("Set3", n_colors=3)

axs = axs.flatten()

for i in range(len(mixed_performance_mae_df)):

    ax = axs[i]
    
    # 데이터 추출
    dataset_name = mixed_performance_mae_df.iloc[i, 0]
    center_perform = mixed_performance_mae_df.iloc[i, 1]
    local_perform = mixed_performance_mae_df.iloc[i, 2]
    fedavg_perform = mixed_performance_mae_df.iloc[i, 3]
    fedprox_perform = mixed_performance_mae_df.iloc[i, 4]
    moon_perform = mixed_performance_mae_df.iloc[i, 5]


    perform_bar = [float(center_perform), float(local_perform), float(fedavg_perform), float(fedprox_perform), float(moon_perform)]

    ax.bar([0, 1, 2], perform_bar[2:], color=colors)

    ax.set_xticks([0, 1, 2])
    ax.set_xticklabels(['FedAvg', 'FedProx', 'MOON'])
    ax.set_ylim(1, np.array(perform_bar).max()*1.1)

    ax.axhline(float(center_perform), color='purple', linestyle='-', linewidth=2, label='Center')
    ax.axhline(float(local_perform), color='navy', linestyle='--', linewidth=2, label='Local')

    ax.set_title(dataset_name, fontsize=16)
    ax.set_xlabel("Model", fontsize=12)
    ax.set_ylabel("Performance", fontsize=12)
    ax.legend(fontsize=15, loc='upper right')


# plt.savefig('/NFS/Users/moonsh/thesis/asset/mixed_MAE_Performance.png', dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(10, 5, figsize=(16, 35))

row=0

for data_idx in range(len(df_per_dataset)):
    df = df_per_dataset[data_idx]
    df = df[df['mode'] == 'Test']

    for col_idx, _type in enumerate(model_type):
        ax = axs[row, col_idx]

        temp_df = df[df['Model'] == _type]
        ax.scatter(temp_df['Age'], temp_df['avg_pred_age'], label=_type, alpha=0.5)
        ax.set_title(f"[{total_data_name[data_idx]}] {_type}", fontsize=12)

        min_age = min(temp_df['Age'].min(), temp_df['avg_pred_age'].min())
        max_age = max(temp_df['Age'].max(), temp_df['avg_pred_age'].max())

        min_age = min_age//5*5 - 5
        max_age = max_age//5*5 + 5
        ax.set_xlim(min_age, max_age)
        ax.set_ylim(min_age, max_age)

        z = np.polyfit(temp_df['Age'], temp_df['avg_pred_age'], 1)
        x = np.linspace(0, 100, 100)
        ax.plot(x, z[0]*x + z[1], color='red', linestyle='--')
        ax.plot([min_age, max_age], [min_age, max_age], color='black', linestyle='-')

        mae = MeanAbsError(temp_df, 'Age', 'avg_pred_age')
        r2 = Correlation(temp_df, 'Age', 'avg_pred_age', method='r2')

        ax.text(0.1, 0.8, f"MAE: {mae:.3f}\nR2: {r2:.3f}", transform=ax.transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))

    row+=1

plt.savefig('/NFS/Users/moonsh/thesis/asset/train-test_scatter_plot.png', dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
# performance_mae_df.to_csv(os.path.join(MERGEBASE, "performance_mae.csv"), index=False, encoding='utf-8')
# performance_r2_df.to_csv(os.path.join(MERGEBASE, "performance_r2.csv"), index=False, encoding='utf-8')

# mixed_performance_mae_df.to_csv(os.path.join(MERGEBASE, "mixed_performance_mae.csv"), index=False)
# mixed_performance_r2_df.to_csv(os.path.join(MERGEBASE, "mixed_performance_r2.csv"), index=False)

# %%
stat_list = []

for data_idx in range(len(df_per_dataset)):
    df = df_per_dataset[data_idx]
    df = df[df['mode'] == 'Test']

    _, new_df = LMEM(df, fixed_cols='Model', random_cols='Subject', dependent_col='AE', intercept="Local", verbose=False)
    stat_list.append(new_df)

# %%
stat_list[9]

# %%
stat_list = []

for data_idx in range(len(df_per_dataset)):
    df = df_per_dataset[data_idx]
    df = df[df['mode'] == 'Test']

    new_df = TukeyHSD(df, fixed_col='Model', dependent_col='AE', verbose=False)
    stat_list.append(new_df)

    # new_df.to_csv(f"/NFS/Users/moonsh/thesis/result/analysis/performance/stat/TukeyHSD_{data_name[data_idx]}.csv", index=False)

# %%
stat_list[2]

# %% [markdown]
# ## Independent DataFrame

# %%
MERGEBASE = "/NFS/Users/moonsh/thesis/result/merge/"

# %%
performance_mae_df = pd.DataFrame(columns=['Dataset', 'Center','FedAvg', 'FedProx', 'MOON'])
performance_r2_df = pd.DataFrame(columns=['Dataset', 'Center', 'FedAvg', 'FedProx', 'MOON'])

mixed_performance_mae_df = pd.DataFrame(columns=['Dataset', 'Center', 'FedAvg', 'FedProx', 'MOON'])
mixed_performance_r2_df = pd.DataFrame(columns=['Dataset', 'Center', 'FedAvg', 'FedProx', 'MOON'])

df_per_dataset = []

for name in ind_data_name:
    temp_model_df = pd.DataFrame()
    TEMPPATH = os.path.join(MERGEBASE, name)

    new_row_mae = {'Dataset': name}
    new_row_r2 = {'Dataset': name}

    mixed_row_mae = {'Dataset': name}
    mixed_row_r2 = {'Dataset': name}

    for _type in ['Center', "FedAvg", "FedProx", "MOON"]:

        temp_save_df = pd.DataFrame()

        if name == 'OAS2' or name == 'SLIM':
            df = pd.read_csv(os.path.join(TEMPPATH, f"{name}_{_type}_base.csv"))
        
        else:
            df = pd.read_csv(os.path.join(TEMPPATH, f"{name}_{_type}.csv"))
        # corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='linear', base_df=df[df['mode'] == 'Train'])

        # test_df = df[df['mode'] == 'Test']

        temp_save_df['Model'] = [_type]*len(df)
        temp_save_df['AE'] = np.abs(df['Age'] - df['avg_pred_age'])
        temp_save_df = pd.concat([temp_save_df, df], axis=1)


        test_df = df.copy()
        if "Control" in test_df.columns:
            test_df = test_df[test_df['Control']=='HC']
        temp_mae_list = []
        temp_r2_list = []

        for pred_idx in range(1, 6):
            temp_mae = MeanAbsError(test_df, 'Age', f"pred_{pred_idx}")
            temp_r2 = Correlation(test_df, 'Age', f"pred_{pred_idx}", method='r2')
            temp_mae_list.extend([temp_mae])
            temp_r2_list.extend([temp_r2])
        
        mae_mean = np.mean(temp_mae_list)
        mae_std = np.std(temp_mae_list)

        r2_mean = np.mean(temp_r2_list)
        r2_std = np.std(temp_r2_list)

        new_row_mae.update({_type: f"{mae_mean:.3f}±{mae_std:.3f}"})
        new_row_r2.update({_type: f"{r2_mean:.3f}±{r2_std:.3f}"})

        mixed_MAE = MeanAbsError(test_df, 'Age', "avg_pred_age")
        mixed_r2 = Correlation(test_df, 'Age', "avg_pred_age", method='r2')

        mixed_row_mae.update({_type: f"{mixed_MAE:.3f}"})
        mixed_row_r2.update({_type: f"{mixed_r2:.3f}"})

        temp_model_df = pd.concat([temp_model_df, temp_save_df], axis=0)

    df_per_dataset.append(temp_model_df)

    mixed_performance_mae_df = pd.concat([mixed_performance_mae_df, pd.DataFrame(mixed_row_mae, index=[0])], axis=0)
    mixed_performance_r2_df = pd.concat([mixed_performance_r2_df, pd.DataFrame(mixed_row_r2, index=[0])], axis=0)

    performance_mae_df = pd.concat([performance_mae_df, pd.DataFrame(new_row_mae, index=[0])], axis=0)
    performance_r2_df = pd.concat([performance_r2_df, pd.DataFrame(new_row_r2, index=[0])], axis=0)

# %%
fig, axs = plt.subplots(9, 4, figsize=(16, 35))

row=0

for data_idx in range(len(df_per_dataset)):
    df = df_per_dataset[data_idx]
    # df = df[df['mode'] == 'Test']

    for col_idx, _type in enumerate(['Center', "FedAvg", "FedProx", "MOON"]):
        ax = axs[row, col_idx]

        temp_df = df[df['Model'] == _type]
        ax.scatter(temp_df['Age'], temp_df['avg_pred_age'], label=_type, alpha=0.5, color='navy')
        ax.set_title(f"[{ind_data_name[data_idx]}] {_type}", fontsize=12)

        min_age = min(temp_df['Age'].min(), temp_df['avg_pred_age'].min())
        max_age = max(temp_df['Age'].max(), temp_df['avg_pred_age'].max())

        min_age = min_age//5*5 - 5
        max_age = max_age//5*5 + 5
        ax.set_xlim(min_age, max_age)
        ax.set_ylim(min_age, max_age)

        z = np.polyfit(temp_df['Age'], temp_df['avg_pred_age'], 1)
        x = np.linspace(0, 100, 100)
        ax.plot(x, z[0]*x + z[1], color='red', linestyle='--')
        ax.plot([min_age, max_age], [min_age, max_age], color='black', linestyle='-')

        mae = MeanAbsError(temp_df, 'Age', 'avg_pred_age')
        r2 = Correlation(temp_df, 'Age', 'avg_pred_age', method='r2')

        ax.text(0.1, 0.8, f"MAE: {mae:.3f}\nR2: {r2:.3f}", transform=ax.transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))

    row+=1

plt.savefig('/NFS/Users/moonsh/thesis/asset/independent_scatter_plot.png', dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
# performance_mae_df.to_csv(os.path.join(MERGEBASE, "ind_performance_mae.csv"), index=False)
# performance_r2_df.to_csv(os.path.join(MERGEBASE, "ind_performance_r2.csv"), index=False)

# mixed_performance_mae_df.to_csv(os.path.join(MERGEBASE, "ind_mixed_performance_mae.csv"), index=False)
# mixed_performance_r2_df.to_csv(os.path.join(MERGEBASE, "ind_mixed_performance_r2.csv"), index=False)

# %%
mixed_performance_mae_df

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

colors = sns.color_palette("Set3", n_colors=3)

axs = axs.flatten()

for i in range(len(mixed_performance_mae_df)):

    ax = axs[i]
    
    # 데이터 추출
    dataset_name = mixed_performance_mae_df.iloc[i, 0]
    center_perform = mixed_performance_mae_df.iloc[i, 1]
    fedavg_perform = mixed_performance_mae_df.iloc[i, 2]
    fedprox_perform = mixed_performance_mae_df.iloc[i, 3]
    moon_perform = mixed_performance_mae_df.iloc[i, 4]


    perform_bar = [float(center_perform), float(fedavg_perform), float(fedprox_perform), float(moon_perform)]

    ax.bar([0, 1, 2], perform_bar[1:], color=colors)

    ax.set_xticks([0, 1, 2])
    ax.set_xticklabels(['FedAvg', 'FedProx', 'MOON'])
    ax.set_ylim(2, np.array(perform_bar).max()*1.1)

    ax.axhline(float(center_perform), color='purple', linestyle='-', linewidth=2, label='Center')

    ax.set_title(dataset_name, fontsize=14)
    # ax.set_xlabel("Model", fontsize=12)
    ax.set_ylabel("Performance", fontsize=12)
    ax.legend(fontsize=13, loc='upper right')


# plt.savefig('/NFS/Users/moonsh/thesis/asset/ind_mixed_MAE_Performance.png', dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
stat_list = []

for data_idx in range(len(df_per_dataset)):
    df = df_per_dataset[data_idx]
    # df = df[df['mode'] == 'Test']

    _, new_df = LMEM(df, fixed_cols='Model', random_cols='Subject', dependent_col='AE', intercept="Center", verbose=False)
    new_df.to_csv(f"/NFS/Users/moonsh/thesis/result/analysis/generalizability/stat/LMEM_{ind_data_name[data_idx]}.csv", index=False)
    stat_list.append(new_df)

# %%
stat_list = []

for data_idx in range(len(df_per_dataset)):
    df = df_per_dataset[data_idx]
    # df = df[df['mode'] == 'Test']

    new_df = TukeyHSD(df, fixed_col='Model', dependent_col='AE', verbose=False)
    new_df.to_csv(f"/NFS/Users/moonsh/thesis/result/analysis/generalizability/stat/Tukey_{ind_data_name[data_idx]}.csv", index=False)
    stat_list.append(new_df)

# %% [markdown]
# ## Patient Analysis

# %%
MERGEBASE = "/NFS/Users/moonsh/thesis/result/merge/"
patient_data_name = ['ADNI', 'OAS4', 'COBRE', 'MCIC', 'NUSDAST']
corr_base_df = pd.read_csv(os.path.join(SAVEPATH, "corr_base_df_only_train.csv"))

# %%
result_list = []
fig, axs = plt.subplots(1, 5, figsize=(35, 6))


for idx, name in enumerate(['ADNI', 'OAS4', 'COBRE', 'MCIC', 'NUSDAST', ]):
    ax = axs[idx]
    
    TEMPPATH = os.path.join(MERGEBASE, name)

    data_df = pd.DataFrame()
    
    for _type in ['Center', "FedAvg", "FedProx", "MOON"]:
        temp_base_df = corr_base_df.copy()
        df = pd.read_csv(os.path.join(TEMPPATH, f"{name}_{_type}.csv"))
        df = df[["Subject", "Age", "avg_pred_age", "Control"]]

        if len(df['Control'].unique()) == 3:
            df["Control"] = pd.Categorical(df["Control"], categories=["HC", "MCI", "AD"], ordered=True)
            
        elif len(df['Control'].unique()) == 2:
            df["Control"] = pd.Categorical(df["Control"], categories=["HC", "SCZ"], ordered=True)
        
        corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=corr_base_df)
        corr_df['model'] = [_type]*len(corr_df)
        corr_df.dropna(inplace=True, axis=0)


        data_df = pd.concat([data_df, corr_df], axis=0)

        # result_dict = {name: {'Model': _type, 'df': corr_df}}
        # result_list.append(result_dict)
    result_list.append(data_df)

    sns.violinplot(data=data_df, x="model", y="corr_PAD", hue="Control", width=0.6, palette="Set3", ax=ax)
    # sns.boxplot(data=data_df, x="model", y="corr_PAD", hue="Control", width=0.6, palette="Set3", ax=ax, showfliers=False)

    # 그래프 설정
    ax.set_title(f"[{name}] Brin Delta", fontsize=22)
    ax.set_xlabel("Model", fontsize=15)
    ax.set_ylabel("Corr. Delta", fontsize=15)
    ax.legend(title="Control", fontsize=14, loc='lower right')
    ax.set_ylim(-4, 4)

# plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', "Patient_Brin_Delta_violin_corr_train_agelevelwCole.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
ind_t_df_SCZ = pd.DataFrame()
ind_t_df_AD = pd.DataFrame()

for name, i in zip(patient_data_name, range(len(result_list))):
    total_df = result_list[i]

    for _type in ['Center', "FedAvg", "FedProx", "MOON"]:
        # print(f"[{name}] {_type}")
        df = total_df[total_df['model']==_type]

        if len(df['Control'].unique()) == 3:
            HC = df[df['Control']=='HC']['corr_PAD']
            MCI = df[df['Control']=='MCI']['corr_PAD']
            AD = df[df['Control']=='AD']['corr_PAD']
            stat1, p1 = ttest_ind(HC, MCI, equal_var=True)
            stat2, p2 = ttest_ind(HC, AD, equal_var=True)

            stat1, p1 = round(stat1, 3), round(p1, 3)
            stat2, p2 = round(stat2, 3), round(p2, 3)

            # print(f"{name}: HC vs MCI - {stat1}, {p1}")
            # print(f"{name}: HC vs AD - {stat2}, {p2}")

            ind_t_df_AD = pd.concat([ind_t_df_AD, pd.DataFrame({'Dataset': [name], 'Model': [_type],
                                                                't_MCI': [stat1], 'p_MCI': [p1],
                                                                't_AD': [stat2], 'p_AD':[p2]})], axis=0)
            
        else:
            HC = df[df['Control']=='HC']['corr_PAD']
            SCZ = df[df['Control']=='SCZ']['corr_PAD']
            stat, p = ttest_ind(HC, SCZ, equal_var=True)

            stat, p = round(stat, 3), round(p, 3)

            # print(f"{name}: HC vs SCZ - {stat}, {p}")

            ind_t_df_SCZ = pd.concat([ind_t_df_SCZ, pd.DataFrame({'Dataset': [name], 'Model': [_type], 't': [stat], 'p': [p]})], axis=0)
    
            
    # print("----------------------------------------------")

# %%
ind_t_df_SCZ

# %%
# ind_t_df_SCZ.to_csv(os.path.join('/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/SCZ_ttest.csv'), index=False)
# ind_t_df_AD.to_csv(os.path.join('/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/AD_ttest.csv'), index=False)

# %%
ind_anova_df_SCZ = pd.DataFrame()
ind_anova_df_AD = pd.DataFrame()

for name, i in zip(patient_data_name, range(len(result_list))):
    total_df = result_list[i]

    for _type in ['Center', "FedAvg", "FedProx", "MOON"]:
        # print(f"[{name}] {_type}")
        df = total_df[total_df['model']==_type]
        if len(df['Control'].unique()) == 3:
            HC = df[df['Control']=='HC']['corr_PAD']
            MCI = df[df['Control']=='MCI']['corr_PAD']
            AD = df[df['Control']=='AD']['corr_PAD']
            stat1, p1 = f_oneway(HC, MCI, AD)
            stat1, p1 = round(stat1, 3), round(p1, 3)

            # print(f"{name}: ANOVA - {stat1}, {p1}")

            ind_anova_df_AD = pd.concat([ind_anova_df_AD, pd.DataFrame({'Dataset': [name], 'Model': [_type],
                                                                'F': [stat1], 'p': [p1]})], axis=0)
            
        else:
            HC = df[df['Control']=='HC']['corr_PAD']
            SCZ = df[df['Control']=='SCZ']['corr_PAD']
            stat, p = f_oneway(HC, SCZ,)

            stat, p = round(stat, 3), round(p, 3)

#            print(f"{name}: ANOVA - {stat}, {p}")

            ind_anova_df_SCZ = pd.concat([ind_anova_df_SCZ, pd.DataFrame({'Dataset': [name], 'Model': [_type], 'F': [stat], 'p': [p]})], axis=0)
    # print("----------------------------------------------")

# %%
ind_anova_df_AD

# %%
ind_anova_df_AD.to_csv(os.path.join('/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/AD_ANOVA.csv'), index=False)
ind_anova_df_SCZ.to_csv(os.path.join('/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/SCZ_ANOVA.csv'), index=False)

# %%
data_list = []

for name, i in zip(patient_data_name, range(len(result_list))):
    total_df = result_list[i]

    for _type in ['Center', "FedAvg", "FedProx", "MOON"]:
        # print(f"[{name}] {_type}")
        df = total_df[total_df['model']==_type]

        if len(df['Control'].unique()) == 3:
            HC = list(df[df['Control']=='HC']['corr_PAD'])
            MCI = list(df[df['Control']=='MCI']['corr_PAD'])
            AD = list(df[df['Control']=='AD']['corr_PAD'])

            data = pd.DataFrame({
                                    'value': HC + MCI + AD,
                                    'group': ['HC'] * len(HC) + ['MCI'] * len(MCI) + ['AD'] * len(AD)
                                })
            
            tukey = pairwise_tukeyhsd(data['value'], data['group'], alpha=0.05)

            if name == 'OAS4' and _type=='FedProx':
                save_data = data
                save_tukey = tukey
            
        else:
            HC = list(df[df['Control']=='HC']['corr_PAD'])
            SCZ = list(df[df['Control']=='SCZ']['corr_PAD'])

            data = pd.DataFrame({
                                    'value': HC + SCZ,
                                    'group': ['HC'] * len(HC) + ['SCZ'] * len(SCZ)
                                })
            
            tukey = pairwise_tukeyhsd(data['value'], data['group'], alpha=0.05)
        
        
        tukey_results = pd.DataFrame(data={
            'Group 1': [pair[0] for pair in tukey._results_table.data[1:]],
            'Group 2': [pair[1] for pair in tukey._results_table.data[1:]],
            'Mean Difference': [pair[2] for pair in tukey._results_table.data[1:]],
            'p-value': [pair[3] for pair in tukey._results_table.data[1:]],
            'Lower Bound': [pair[4] for pair in tukey._results_table.data[1:]],
            'Upper Bound': [pair[5] for pair in tukey._results_table.data[1:]],
            'Reject H0': [pair[6] for pair in tukey._results_table.data[1:]],
        })

        data_list.append(tukey_results)
        
        # tukey_results.to_csv(f"/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/Tukey_{name}_{_type}.csv", index=False)

    # print("----------------------------------------------")

# %%
data_list[19]

# %%
# ind_anova_df_AD.to_csv(os.path.join('/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/AD_ANOVA.csv'), index=False)
# ind_anova_df_SCZ.to_csv(os.path.join('/NFS/Users/moonsh/thesis/result/analysis/patient/corr_train_age_level_wCole/SCZ_ANOVA.csv'), index=False)

# %% [markdown]
# ## Consistency

# %%
OAS2_interval_list = [70, 80, 90]
SLIM_interval_list = [20, 22, 24, 26]

data = 'SLIM'
MERGEBASE = f"/NFS/Users/moonsh/thesis/result/merge/{data}"

# %%
total_df = pd.DataFrame()

for _mode in ["Center", "FedAvg", "FedProx", "MOON"]:

    temp_df = pd.DataFrame()
    base_df = pd.read_csv(os.path.join(MERGEBASE, f"{data}_{_mode}_base.csv"))
    follow_df = pd.read_csv(os.path.join(MERGEBASE, f"{data}_{_mode}_follow.csv"))

    base_df.sort_values(by='Subject', inplace=True)
    follow_df.sort_values(by='Subject', inplace=True)

    temp_df['Subject'] = base_df['Subject']
    temp_df['real_age_1'] = base_df['Age']
    temp_df['real_age_2'] = follow_df['Age']
    temp_df['pred_age_1'] = base_df['avg_pred_age']
    temp_df['pred_age_2'] = follow_df['avg_pred_age']
    temp_df['model'] = [_mode]*len(temp_df)

    total_df = pd.concat([total_df, temp_df], axis=0)

# %%
consistency_performance_table, result_df = Longitudinal_performance(total_df, SLIM_interval_list, verbose=True) # OAS2_interval_list, SLIM_interval_list
new_df, lmem_result = LMEM(result_df, random_cols='Subject', fixed_cols='model', dependent_col='abs_gap_diff', intercept="Center", verbose=True)
# lmem_result.to_csv(f"/NFS/Users/moonsh/thesis/result/analysis/consistency/LMEM_{data}_consistency.csv", index=False)

# %%
consistency_performance_table

# %%
tukey_result = TukeyHSD(result_df, fixed_col='model', dependent_col='abs_gap_diff')
# tukey_result.to_csv(f"/NFS/Users/moonsh/thesis/result/analysis/consistency/Tukey_{data}_consistency.csv", index=False)

# %%
center = result_df[result_df['model']=='Center']['abs_gap_diff']
fedavg = result_df[result_df['model']=='FedAvg']['abs_gap_diff']
fedprox = result_df[result_df['model']=='FedProx']['abs_gap_diff']
moon = result_df[result_df['model']=='MOON']['abs_gap_diff']

stat1, p1 = f_oneway(center, fedavg, fedprox, moon)
print(stat1, p1)

# %%
tukey_result

# %% [markdown]
# ## Association

# %% [markdown]
# ### COBRE

# %%
model_list = ['Center', 'FedAvg', 'FedProx', 'MOON']
RESULTBASE = '/NFS/Users/moonsh/thesis/result/merge/COBRE'

score_list = ['Positive Scale', 'Negative Scale', 'General Psychopathology Scale', 'Total',
                  "WASI_Vocab_RawScore",
            "WASI_Similarities_RawScore",
    "HVLT_Trials_Sum",
    "WASI_BlockDesign_RawScore",
    "LNS_RawScore",
    "TMT_A_RawScore",
    "FAS_F",
    "FAS_A",
    "FAS_S"
]
corr_base_df = pd.read_csv(os.path.join(SAVEPATH, "corr_base_df_only_train.csv"))

# %%
df['Control'].value_counts()

# %%
fig, axs = plt.subplots(1, 4 , figsize=(15, 4))

axs= axs.flatten()

for i, model in enumerate(model_list):
    df = pd.read_csv(os.path.join(RESULTBASE, f"COBRE_{model}.csv"))
    
    temp_base_df = corr_base_df.copy()
    temp_base_df = pd.concat([temp_base_df, df[df['Control']=="HC"]], axis=0)

    corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=temp_base_df)
    corr_df = corr_df[corr_df['Control']=='HC']

    sns.regplot(x='Age', y='corr_PAD', data=corr_df, ax=axs[i], fit_reg=True, color='navy', scatter_kws={'alpha':0.7})
    
    axs[i].plot([min(corr_df['Age']), max(corr_df['Age'])], [0, 0], color='black', linestyle='--')
    axs[i].set_title(f"[COBRE] {model}", fontsize=15)
    axs[i].set_ylim(-25, 25)
    axs[i].set_ylabel("Corr. BrainPAD", fontsize=12)
    axs[i].set_xlabel("Age", fontsize=12)

# plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', f"COBRE_corrBrainPAD_scatter_plot.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(len(score_list), 4 , figsize=(20, 45))

for i, model in enumerate(model_list):
    df = pd.read_csv(os.path.join(RESULTBASE, f"COBRE_{model}.csv"))

    cobre_neuropsych_df = pd.read_csv(os.path.join(PHENOPATH, 'COBRE', '1139_Cobre_Neuropsych_V2_20210127.csv'))
    cobre_neuropsych_df.drop('Control', axis=1, inplace=True)

    corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=corr_base_df) 
    cobre_neuropsych_df = pd.concat([cobre_neuropsych_df.iloc[:, :2], cobre_neuropsych_df.iloc[:, 8:-1]], axis=1)
    corr_df = pd.merge(corr_df, cobre_neuropsych_df, on='Subject', how='left')
    corr_df = corr_df[corr_df['Control']=='SCZ']


    r_list = []
    p_list = []
    for col, score in enumerate(score_list):
        ax = axs[col, i]

        temp_df = corr_df.copy()
        temp_df.dropna(subset=score, axis=0, inplace=True)
        temp_df.dropna(subset=['corr_PAD'], axis=0, inplace=True)

        temp_df[score].replace(['MD',], np.nan, inplace=True)
        temp_df.dropna(subset=[score], axis=0, inplace=True)
        temp_df[score] = temp_df[score].astype(float)

        scores = temp_df[score]
        corr_ba = temp_df['corr_PAD']

        r, p = pearsonr(scores, corr_ba)
        r= round(r, 3)
        p= round(p, 3)

        sns.regplot(x='corr_PAD', y=score, data=temp_df, ax=ax, fit_reg=True, color='navy', scatter_kws={'alpha':0.7})
        
        if score =='Total':
            ax.set_title(f"[{model}] PANSS Total (n={len(temp_df)}))", fontsize=12)

        else:
            ax.set_title(f"[{model}] {score} (n={len(temp_df)})", fontsize=12)

        ax.set_xlabel("Corrected BrainPAD", fontsize=12)
        ax.set_ylabel("Score", fontsize=12)

        r_list.extend([r])
        p_list.extend([p])
    
    fdr = fdrcorrection(p_list, alpha=0.05)[1]

    for col, _ in enumerate(score_list):
        ax = axs[col, i]
        r= r_list[col]
        p = fdr[col]
        ax.text(0.1, 0.85, f"r: {r:.3f}\n$p_{{FDR}}: {p:.3f}$", transform=ax.transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.9))


plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', f"COBRE_SCZ_corr_scatter_plot.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### MCIC

# %%
name_key = {
    'Positive Symptoms': 'Positive Scale',
    'Negative Symptoms': 'Negative Scale',
    'Vocabulary Total Raw Score': 'WASI_Vocab_RawScore',
    'Similarities Total Raw Score': 'WASI_Similarities_RawScore',
    'Recall Total Score': 'HVLT_Trials_Sum',
    'Block Design Total Raw Score': 'WASI_BlockDesign_RawScore',
    'Letter-Number Total Raw Score': 'LNS_RawScore',
    'Trials A: Time': 'TMT_A_RawScore',
    'Total FAS' : 'FAS_S',
    'Animals': 'FAS_A', 
    'Fruits': 'FAS_F',
}

# %%
data = "MCIC"

model_list = ['Center', 'FedAvg', 'FedProx', 'MOON']
RESULTBASE = f'/NFS/Users/moonsh/thesis/result/merge/{data}'

score_list = name_key.values()

corr_base_df = pd.read_csv(os.path.join(SAVEPATH, "corr_base_df_only_train.csv"))

# %%
fig, axs = plt.subplots(1, 4 , figsize=(15, 4))

axs= axs.flatten()

for i, model in enumerate(model_list):
    df = pd.read_csv(os.path.join(RESULTBASE, f"{data}_{model}.csv"))

    corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=corr_base_df)
    corr_df = corr_df[corr_df['Control']=='HC']

    sns.regplot(x='Age', y='corr_PAD', data=corr_df, ax=axs[i], fit_reg=True, color='navy', scatter_kws={'alpha':0.7})
    
    axs[i].plot([min(corr_df['Age']), max(corr_df['Age'])], [0, 0], color='black', linestyle='--')
    axs[i].set_title(f"[{data}] {model}", fontsize=15)
    axs[i].set_ylim(-25, 25)
    axs[i].set_ylabel("Corr. BrainPAD", fontsize=12)
    axs[i].set_xlabel("Age", fontsize=12)

# plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', f"MCIC_corrBrainPAD_scatter_plot.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(len(score_list), 4, figsize=(20, 45))

for i, model in enumerate(model_list):
    df = pd.read_csv(os.path.join(RESULTBASE, f"{data}_{model}.csv"))

    corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=corr_base_df)
    corr_df = corr_df[corr_df['Control']=='SCZ']

    corr_df.rename(columns=name_key, inplace=True)
    p_list = []
    r_list = []
    for col, score in enumerate(score_list):
        ax = axs[col, i]

        temp_df = corr_df.copy()
        temp_df.dropna(subset=score, axis=0, inplace=True)
        temp_df.dropna(subset=['corr_PAD'], axis=0, inplace=True)

        temp_df[score].replace(['DK', "MD"], np.nan, inplace=True)
        temp_df.dropna(subset=[score], axis=0, inplace=True)
        temp_df[score] = temp_df[score].astype(float)

        scores = temp_df[score]
        corr_ba = temp_df['corr_PAD']

        r, p = pearsonr(scores, corr_ba)
        # r= round(r, 3)
        # p= round(p, 3)

        sns.regplot(x='corr_PAD', y=score, data=temp_df, ax=ax, fit_reg=True, color='navy', scatter_kws={'alpha':0.7})

        if score =='Total':
            ax.set_title(f"[{model}] PANSS Total", fontsize=12)

        else:
            ax.set_title(f"[{model}] {score} (n={len(temp_df)})", fontsize=12)

        ax.set_xlabel("Corrected BrainPAD", fontsize=12)
        ax.set_ylabel("Score", fontsize=12)

        r_list.extend([r])
        p_list.extend([p])
    
    fdr = fdrcorrection(p_list, alpha=0.05)[1]

    for col, _ in enumerate(score_list):
        ax = axs[col, i]
        r= r_list[col]
        p = fdr[col]
        ax.text(0.1, 0.85, f"r: {r:.3f}\n$p_{{FDR}}: {p:.3f}$", transform=ax.transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.9))


plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', f"MCIC_SCZ_corr_scatter_plot.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### OASIS-4

# %%
data = "OAS4"

model_list = ['Center', 'FedAvg', 'FedProx', 'MOON']
RESULTBASE = f'/NFS/Users/moonsh/thesis/result/merge/{data}'

score_list = [
    "mem_word",
    "digitsym_second",
    "boston",
    "recall_word",
    "short_blessed",
    'traila_sec',
    'trailb_sec',
    "logimem",
    "gds_total",
]

corr_base_df = pd.read_csv(os.path.join(SAVEPATH, "corr_base_df_only_train.csv"))
neuro_df = pd.read_csv(os.path.join(PHENOPATH, 'OAS4', 'OASIS4_data_Neuropsychometric.csv'))
neuro_df = neuro_df[['Subject']+score_list]

# %%
fig, axs = plt.subplots(1, 4 , figsize=(15, 4))

axs= axs.flatten()

for i, model in enumerate(model_list):
    df = pd.read_csv(os.path.join(RESULTBASE, f"{data}_{model}.csv"))

    corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=corr_base_df)
    corr_df = corr_df[corr_df['Control']=='HC']

    sns.regplot(x='Age', y='corr_PAD', data=corr_df, ax=axs[i], fit_reg=True, color='navy', scatter_kws={'alpha':0.7})
    
    axs[i].plot([min(corr_df['Age']), max(corr_df['Age'])], [0, 0], color='black', linestyle='--')
    axs[i].set_title(f"[{data}] {model}", fontsize=15)
    axs[i].set_ylim(-25, 25)
    axs[i].set_ylabel("Corr. BrainPAD", fontsize=12)
    axs[i].set_xlabel("Age", fontsize=12)

# plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', f"OAS4_corrBrainPAD_scatter_plot.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(len(score_list), 4, figsize=(15, 30))

for i, model in enumerate(model_list):
    df = pd.read_csv(os.path.join(RESULTBASE, f"{data}_{model}.csv"))

    corr_df = BiasCorrection(df, 'Age', 'avg_pred_age', method='age_level_wCole', base_df=corr_base_df)
    # corr_df = corr_df[corr_df['Control']=='AD']
    corr_df = corr_df[(corr_df['Control'] == 'AD') | (corr_df['Control'] == 'MCI')]


    corr_df = pd.merge(corr_df, neuro_df, on='Subject', how='left')

    r_list = []
    p_list = []

    for col, score in enumerate(score_list):
        ax = axs[col, i]

        temp_df = corr_df.copy()
        temp_df.dropna(subset=score, axis=0, inplace=True)
        temp_df.dropna(subset=['corr_PAD'], axis=0, inplace=True)

        temp_df[score].replace(['M', "C", "R", "DK", "I"], np.nan, inplace=True)
        temp_df.dropna(subset=[score], axis=0, inplace=True)
        temp_df[score] = temp_df[score].astype(float)

        scores = temp_df[score]
        corr_ba = temp_df['corr_PAD']

        r, p = pearsonr(scores, corr_ba)
        r= round(r, 3)
        p= round(p, 3)

        sns.regplot(x='corr_PAD', y=score, data=temp_df, ax=ax, fit_reg=True, color='navy', scatter_kws={'alpha':0.7})
        
        if score =='Total':
            ax.set_title(f"[{model}] PANSS Total", fontsize=12)

        else:
            ax.set_title(f"[{model}] {score} (n={len(temp_df)})", fontsize=12)

        ax.set_xlabel("Corrected BrainPAD", fontsize=12)
        ax.set_ylabel("Score", fontsize=12)


        r_list.extend([r])
        p_list.extend([p])
    
    fdr = fdrcorrection(p_list, alpha=0.05)[1]

    for col, _ in enumerate(score_list):
        ax = axs[col, i]
        r= r_list[col]
        p = fdr[col]
        ax.text(0.1, 0.85, f"r: {r:.3f}\n$p_{{FDR}}: {p:.3f}$", transform=ax.transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.9))

# plt.savefig(os.path.join('/NFS/Users/moonsh/thesis/asset', f"OAS4_AD+MCI_corr_scatter_plot.png"), dpi=600, bbox_inches='tight', format='png', pad_inches=0.2)
plt.tight_layout()
plt.show()
